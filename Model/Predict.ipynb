# %%
from fastai.vision import *

# %%
# !pwd
# Out:
# /home/weerayuth/ImTrash

# %%
path = "/home/weerayuth/ImTrash"

# %%
learn = load_learner(path,'trained_model_ResNet50_7.41E-04_e40.pkl') #RESNET50 50e

# %%
learn
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: /home/weerayuth/ImTrash;
#
# Valid: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: /home/weerayuth/ImTrash;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
data = open_image('NEW/IMG_25621201_211943.jpg')
data = data.resize((3,384,512))
data
# Out:
# Image (3, 2592, 4608)

# %%
# preds = learn.predict(data)
# preds
predicted_class, predicted_index, outputs = learn.predict(data)
predicted_class
# Out:
# Category glass

# %%
group = str(predicted_class)
group
# Out:
# 'glass'
